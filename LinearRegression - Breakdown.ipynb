# %% [markdown]
# We're writing our code for LinearRegression here, hail ***SENTDEX***

# %%
from statistics import mean
import math 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import random
style.use('fivethirtyeight')

# %%
xs = [1,2,3,4,5,6,]
xs = np.array(xs,dtype=np.float64)
ys = [5,4,6,5,6,7,]
ys = np.array(ys,dtype=np.float64)

def bestfitslopeandintercept(xs,ys):
  m = ((mean(xs) * mean(ys) - mean(xs*ys))  /
      (mean(xs)*mean(xs) - mean(xs*xs)))
  b = mean(ys) - m*mean(xs)
  return m,b

m,b = bestfitslopeandintercept(xs,ys)


reg_line = [(m*x)+b for x in xs]

# %% [markdown]
# This shit has defined the value for m i.e. Slope
#
#
# ![Forumla](data:image/png;base64,...)

# %%
plt.scatter(xs,ys)
plt.plot(xs,reg_line)
plt.show()

# %%
predict_x = 8

predict_y = m*predict_x+b
plt.scatter(predict_x,predict_y,color = 'g')
plt.plot(xs,reg_line)
plt.show()

# %% [markdown]
# **Now figure out, how accurate this is **
#
# #Part 10 of ML series

# %%
# def squared_error(ys_orig,ys_line):
#   return sum((ys_line-ys_orig)**2)

# def coefficient_of_determination(ys_orig,ys_line):          #This is the "B"
#   y_mean_line = [mean(ys_orig) for y in ys_orig]
#   squared_error_regr =  squared_error(ys_orig,ys_line):
# Out:
#   File "<ipython-input-27-9f6e988ceefc>", line 6
#     squared_error_regr =  squared_error(ys_orig,ys_line):
#                                                         ^
# SyntaxError: invalid syntax

# %%
# create_dataset(hm,variance, step = 2,correlation=False):
#   val =  1
#   ys = []
#   for i in range(hm):
#     y = val + random.randrange(-variance,variance)
#     ys.append(y)
#   np.array((xs,datatype=np.float64),(ys,dtype=np.float64))
